# %%
import pandas as pd
import matplotlib

# %%
ts = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

# %%
mercer = ts[(ts.fips == 34021.0)]

# %%
mercer.head(2)
# Out:
#             date  county       state     fips  cases  deaths
# 2144  2020-03-14  Mercer  New Jersey  34021.0      1       0
# 2552  2020-03-15  Mercer  New Jersey  34021.0      1       0

# %%
mercer.plot(x='date', y='cases', ylim=(0,12000))

# %%
bergen = ts[(ts.fips == 34003.0)]
bergen.plot(x='date', y='cases', ylim=(0,12000))

# %%
ts[(ts.state == 'New Jersey')].head(20)
# Out:
#             date      county       state     fips  cases  deaths
# 517   2020-03-04      Bergen  New Jersey  34003.0      1       0
# 563   2020-03-05      Bergen  New Jersey  34003.0      2       0
# 624   2020-03-06      Bergen  New Jersey  34003.0      3       0
# 625   2020-03-06      Camden  New Jersey  34007.0      1       0
# 712   2020-03-07      Bergen  New Jersey  34003.0      3       0
# 713   2020-03-07      Camden  New Jersey  34007.0      1       0
# 816   2020-03-08      Bergen  New Jersey  34003.0      4       0
# 817   2020-03-08      Camden  New Jersey  34007.0      1       0
# 818   2020-03-08     Passaic  New Jersey  34031.0      1       0
# 940   2020-03-09      Bergen  New Jersey  34003.0      5       0
# 941   2020-03-09      Camden  New Jersey  34007.0      1       0
# 942   2020-03-09      Hudson  New Jersey  34017.0      1       0
# 943   2020-03-09    Monmouth  New Jersey  34025.0      2       0
# ...

# %%
ts.plot?
# Out:
# Signature:      ts.plot(*args, **kwargs)
# Type:           PlotAccessor
# String form:    <pandas.plotting._core.PlotAccessor object at 0x7f6af65e0a50>
# File:           /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/plotting/_core.py
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
# ...
