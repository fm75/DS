# %%
import pandas as pd
from pathlib import Path

county_population_path = Path('../data/co-est2019-alldata.csv')

def us_county_population(csvfile: Path) -> pd.DataFrame:
    population = pd.read_csv(csvfile, encoding = "ISO-8859-1")
    population = population[["STNAME", 'CTYNAME', 'POPESTIMATE2019']]
    return population.rename(columns={"STNAME": "state", "CTYNAME": "county", "POPESTIMATE2019": "pop2019"})
    return population

# %%
county_pop = us_county_population(county_population_path)
county_pop
# Out:
#         state             county  pop2019
# 0     Alabama            Alabama  4903185
# 1     Alabama     Autauga County    55869
# 2     Alabama     Baldwin County   223234
# 3     Alabama     Barbour County    24686
# 4     Alabama        Bibb County    22394
# ...       ...                ...      ...
# 3188  Wyoming  Sweetwater County    42343
# 3189  Wyoming       Teton County    23464
# 3190  Wyoming       Uinta County    20226
# 3191  Wyoming    Washakie County     7805
# 3192  Wyoming      Weston County     6927
#
# [3193 rows x 3 columns]
