# %%
import pandas as pd
import requests

county_population_url = 'https://www.newjersey-demographics.com/counties_by_population'

# %%
def county_population(url: str) -> pd.DataFrame:
    header = {
      "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
      "X-Requested-With": "XMLHttpRequest"
    }

    r = requests.get(url, headers=header)
    population = pd.read_html(r.text, header=[0], index_col=0, skiprows=[22])[0]
    population = population[['County', 'Population']]
    return population.rename(columns={"County": "county", "Population": "pop2019"})

# %%
county_population(county_population_url)
# Out:
#                  county  pop2019
# Rank
# 1         Bergen County   929999
# 2      Middlesex County   826698
# 3          Essex County   793555
# 4         Hudson County   668631
# 5       Monmouth County   623387
# 6          Ocean County   591939
# 7          Union County   553066
# 8         Camden County   507367
# 9        Passaic County   504041
# 10        Morris County   494383
# 11    Burlington County   446367
# 12        Mercer County   368762
# 13      Somerset County   330176
# 14    Gloucester County   290852
# 15      Atlantic County   268539
# 16    Cumberland County   153400
# 17        Sussex County   142298
# 18     Hunterdon County   125051
# 19        Warren County   106293
# 20      Cape May County    93705
# 21         Salem County    63336
