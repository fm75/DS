# %%
import sys
sys.path.append('../src')

# %%
from covid import daily_snapshot
from pathlib import Path

import population as pop
import pandas as pd
import requests

# %%
pd.set_option('max_rows', 100)

# %%
url = 'https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports/03-31-2020.csv'

# %% [markdown]
# ### Quick glance at the data

# %%
df = daily_snapshot('03-31-2020')
df.head()
# Out:
#          Unnamed: 0     Admin2  Province_State Country_Region  \
# FIPS
# 45001.0         NaN  Abbeville  South Carolina             US
# 22001.0         NaN     Acadia       Louisiana             US
# 51001.0         NaN   Accomack        Virginia             US
# 16001.0         NaN        Ada           Idaho             US
# 19001.0         NaN      Adair            Iowa             US
#
#                  Last_Update        Lat       Long_  Confirmed  Deaths  \
# FIPS
# 45001.0  2020-03-31 23:43:56  34.223334  -82.461707          4       0
# 22001.0  2020-03-31 23:43:56  30.295065  -92.414197         39       1
# 51001.0  2020-03-31 23:43:56  37.767072  -75.632346          7       0
# 16001.0  2020-03-31 23:43:56  43.452658 -116.241552        195       3
# 19001.0  2020-03-31 23:43:56  41.330756  -94.471059          1       0
#
#          Recovered  Active                   Combined_Key
# FIPS
# 45001.0          0       0  Abbeville, South Carolina, US
# 22001.0          0       0          Acadia, Louisiana, US
# 51001.0          0       0         Accomack, Virginia, US
# 16001.0          0       0                 Ada, Idaho, US
# 19001.0          0       0                Adair, Iowa, US

# %%
df[df.Country_Region=='US'].describe()
# Out:
#        Unnamed: 0          Lat        Long_     Confirmed       Deaths  \
# count         0.0  2177.000000  2177.000000   2179.000000  2179.000000
# mean          NaN    37.226079   -88.658406     86.357045     1.777421
# std           NaN     7.057726    18.503999   1004.773418    23.680408
# min           NaN     0.000000  -159.596679      0.000000     0.000000
# 25%           NaN    33.953399   -95.539078      2.000000     0.000000
# 50%           NaN    37.841579   -87.722071      5.000000     0.000000
# 75%           NaN    41.408032   -81.956663     20.000000     0.000000
# max           NaN    64.807262   145.673900  43119.000000   932.000000
#
#          Recovered  Active
# count  2179.000000  2179.0
# mean      3.223497     0.0
# std     150.472067     0.0
# min       0.000000     0.0
# 25%       0.000000     0.0
# 50%       0.000000     0.0
# 75%       0.000000     0.0
# max    7024.000000     0.0

# %% [markdown]
# ### Aggregate by state

# %%
state_totals = df[df.Country_Region=='US'].groupby(by='Province_State').sum()

# %%
state_totals.describe()
# Out:
#        Unnamed: 0          Lat         Long_     Confirmed       Deaths  \
# count        58.0    58.000000     58.000000     58.000000    58.000000
# mean          0.0  1397.261622  -3327.747410   3244.344828    66.775862
# std           0.0  1154.954186   2887.627484  10179.628981   208.850660
# min           0.0     0.000000 -13378.805429      0.000000     0.000000
# 25%           0.0   418.858961  -5190.570613    252.500000     4.250000
# 50%           0.0  1152.194028  -3017.705127    659.500000    12.500000
# 75%           0.0  2292.925088   -864.637952   2343.000000    52.750000
# max           0.0  4531.701456    145.673900  75833.000000  1550.000000
#
#          Recovered  Active
# count    58.000000    58.0
# mean    121.103448     0.0
# std     922.296384     0.0
# min       0.000000     0.0
# 25%       0.000000     0.0
# 50%       0.000000     0.0
# 75%       0.000000     0.0
# max    7024.000000     0.0

# %%
state = 'New Jersey'
state_covid = df[df.Province_State == state]
state_columns=['Admin2', 'Confirmed', 'Deaths', 'Recovered', 'Active', ]

# %%
state_covid[state_columns].sort_values(by='Confirmed', ascending=False)
# Out:
#              Admin2  Confirmed  Deaths  Recovered  Active
# FIPS
# NaN      Unassigned       3686     247          0       0
# 34003.0      Bergen       2909       4          0       0
# 34013.0       Essex       1900       4          0       0
# 34017.0      Hudson       1606       2          0       0
# 34039.0       Union       1418       0          0       0
# 34031.0     Passaic       1294       1          0       0
# 34023.0   Middlesex       1277       0          0       0
# 34025.0    Monmouth       1140       2          0       0
# 34029.0       Ocean       1022       1          0       0
# 34027.0      Morris        841       1          0       0
# 34035.0    Somerset        413       1          0       0
# 34021.0      Mercer        268       0          0       0
# 34007.0      Camden        228       3          0       0
# 34005.0  Burlington        202       0          0       0
# 34037.0      Sussex        132       0          0       0
# 34015.0  Gloucester        114       0          0       0
# 34019.0   Hunterdon         97       0          0       0
# 34041.0      Warren         76       0          0       0
# 34001.0    Atlantic         31       0          0       0
# 34011.0  Cumberland         18       1          0       0
# 34033.0       Salem         12       0          0       0
# 34009.0    Cape May         12       0          0       0

# %%
state_covid[state_columns].sort_values(by='Deaths', ascending=False)
# Out:
#              Admin2  Confirmed  Deaths  Recovered  Active
# FIPS
# NaN      Unassigned       3686     247          0       0
# 34013.0       Essex       1900       4          0       0
# 34003.0      Bergen       2909       4          0       0
# 34007.0      Camden        228       3          0       0
# 34017.0      Hudson       1606       2          0       0
# 34025.0    Monmouth       1140       2          0       0
# 34031.0     Passaic       1294       1          0       0
# 34011.0  Cumberland         18       1          0       0
# 34035.0    Somerset        413       1          0       0
# 34027.0      Morris        841       1          0       0
# 34029.0       Ocean       1022       1          0       0
# 34001.0    Atlantic         31       0          0       0
# 34039.0       Union       1418       0          0       0
# 34037.0      Sussex        132       0          0       0
# 34033.0       Salem         12       0          0       0
# 34023.0   Middlesex       1277       0          0       0
# 34021.0      Mercer        268       0          0       0
# 34019.0   Hunterdon         97       0          0       0
# 34015.0  Gloucester        114       0          0       0
# 34009.0    Cape May         12       0          0       0
# 34005.0  Burlington        202       0          0       0
# 34041.0      Warren         76       0          0       0

# %%
nj_county_population_url = 'https://www.newjersey-demographics.com/counties_by_population'

# %%
nj_pop = pop.nj_county_population(nj_county_population_url)

# %%
nj_pop
# Out:
#                  county  pop2019
# Rank
# 1         Bergen County   929999
# 2      Middlesex County   826698
# 3          Essex County   793555
# 4         Hudson County   668631
# 5       Monmouth County   623387
# 6          Ocean County   591939
# 7          Union County   553066
# 8         Camden County   507367
# 9        Passaic County   504041
# 10        Morris County   494383
# 11    Burlington County   446367
# 12        Mercer County   368762
# 13      Somerset County   330176
# 14    Gloucester County   290852
# 15      Atlantic County   268539
# 16    Cumberland County   153400
# 17        Sussex County   142298
# 18     Hunterdon County   125051
# 19        Warren County   106293
# 20      Cape May County    93705
# 21         Salem County    63336

# %%
nj_pop['county'] = nj_pop['county'].apply(lambda x: str(x)[:-7])

# %%
nj_pop.head(1)
# Out:
#       county  pop2019
# Rank
# 1     Bergen   929999

# %%
state_with_population = pd.merge(state_covid[state_columns], nj_pop,left_on='Admin2', right_on='county')

state_with_population['fraction_confirmed'] = state_with_population['Confirmed'] / state_with_population['pop2019']   * 100.0
state_with_population['deaths']             = state_with_population['Deaths']    / state_with_population['pop2019']   * 100.0
state_with_population['death_rate?']        = state_with_population['Deaths']    / state_with_population['Confirmed'] * 100.0

# %%
state_with_population.sort_values(by='fraction_confirmed', ascending=False)
# Out:
#         Admin2  Confirmed  Deaths  Recovered  Active      county  pop2019  \
# 1       Bergen       2909       4          0       0      Bergen   929999
# 15     Passaic       1294       1          0       0     Passaic   504041
# 19       Union       1418       0          0       0       Union   553066
# 8       Hudson       1606       2          0       0      Hudson   668631
# 6        Essex       1900       4          0       0       Essex   793555
# 12    Monmouth       1140       2          0       0    Monmouth   623387
# 14       Ocean       1022       1          0       0       Ocean   591939
# 13      Morris        841       1          0       0      Morris   494383
# 11   Middlesex       1277       0          0       0   Middlesex   826698
# 17    Somerset        413       1          0       0    Somerset   330176
# 18      Sussex        132       0          0       0      Sussex   142298
# 9    Hunterdon         97       0          0       0   Hunterdon   125051
# 10      Mercer        268       0          0       0      Mercer   368762
# 20      Warren         76       0          0       0      Warren   106293
# 2   Burlington        202       0          0       0  Burlington   446367
# 3       Camden        228       3          0       0      Camden   507367
# 7   Gloucester        114       0          0       0  Gloucester   290852
# 16       Salem         12       0          0       0       Salem    63336
# 4     Cape May         12       0          0       0    Cape May    93705
# 5   Cumberland         18       1          0       0  Cumberland   153400
# 0     Atlantic         31       0          0       0    Atlantic   268539
#
#     fraction_confirmed    deaths  death_rate?
# 1             0.312796  0.000430     0.137504
# 15            0.256725  0.000198     0.077280
# 19            0.256389  0.000000     0.000000
# 8             0.240192  0.000299     0.124533
# 6             0.239429  0.000504     0.210526
# 12            0.182872  0.000321     0.175439
# 14            0.172653  0.000169     0.097847
# 13            0.170111  0.000202     0.118906
# 11            0.154470  0.000000     0.000000
# 17            0.125085  0.000303     0.242131
# 18            0.092763  0.000000     0.000000
# 9             0.077568  0.000000     0.000000
# 10            0.072676  0.000000     0.000000
# 20            0.071500  0.000000     0.000000
# 2             0.045254  0.000000     0.000000
# 3             0.044938  0.000591     1.315789
# 7             0.039195  0.000000     0.000000
# 16            0.018947  0.000000     0.000000
# 4             0.012806  0.000000     0.000000
# 5             0.011734  0.000652     5.555556
# 0             0.011544  0.000000     0.000000

# %%
state_with_population.sort_values(by='Deaths', ascending=False)
# Out:
#         Admin2  Confirmed  Deaths  Recovered  Active      county  pop2019  \
# 6        Essex       1900       4          0       0       Essex   793555
# 1       Bergen       2909       4          0       0      Bergen   929999
# 3       Camden        228       3          0       0      Camden   507367
# 8       Hudson       1606       2          0       0      Hudson   668631
# 12    Monmouth       1140       2          0       0    Monmouth   623387
# 14       Ocean       1022       1          0       0       Ocean   591939
# 5   Cumberland         18       1          0       0  Cumberland   153400
# 17    Somerset        413       1          0       0    Somerset   330176
# 15     Passaic       1294       1          0       0     Passaic   504041
# 13      Morris        841       1          0       0      Morris   494383
# 0     Atlantic         31       0          0       0    Atlantic   268539
# 19       Union       1418       0          0       0       Union   553066
# 18      Sussex        132       0          0       0      Sussex   142298
# 16       Salem         12       0          0       0       Salem    63336
# 10      Mercer        268       0          0       0      Mercer   368762
# 11   Middlesex       1277       0          0       0   Middlesex   826698
# 9    Hunterdon         97       0          0       0   Hunterdon   125051
# 7   Gloucester        114       0          0       0  Gloucester   290852
# 4     Cape May         12       0          0       0    Cape May    93705
# 2   Burlington        202       0          0       0  Burlington   446367
# 20      Warren         76       0          0       0      Warren   106293
#
#     fraction_confirmed    deaths  death_rate?
# 6             0.239429  0.000504     0.210526
# 1             0.312796  0.000430     0.137504
# 3             0.044938  0.000591     1.315789
# 8             0.240192  0.000299     0.124533
# 12            0.182872  0.000321     0.175439
# 14            0.172653  0.000169     0.097847
# 5             0.011734  0.000652     5.555556
# 17            0.125085  0.000303     0.242131
# 15            0.256725  0.000198     0.077280
# 13            0.170111  0.000202     0.118906
# 0             0.011544  0.000000     0.000000
# 19            0.256389  0.000000     0.000000
# 18            0.092763  0.000000     0.000000
# 16            0.018947  0.000000     0.000000
# 10            0.072676  0.000000     0.000000
# 11            0.154470  0.000000     0.000000
# 9             0.077568  0.000000     0.000000
# 7             0.039195  0.000000     0.000000
# 4             0.012806  0.000000     0.000000
# 2             0.045254  0.000000     0.000000
# 20            0.071500  0.000000     0.000000

# %%
state_with_population.sort_values(by='death_rate?', ascending=False)
# Out:
#         Admin2  Confirmed  Deaths  Recovered  Active      county  pop2019  \
# 5   Cumberland         18       1          0       0  Cumberland   153400
# 3       Camden        228       3          0       0      Camden   507367
# 17    Somerset        413       1          0       0    Somerset   330176
# 6        Essex       1900       4          0       0       Essex   793555
# 12    Monmouth       1140       2          0       0    Monmouth   623387
# 1       Bergen       2909       4          0       0      Bergen   929999
# 8       Hudson       1606       2          0       0      Hudson   668631
# 13      Morris        841       1          0       0      Morris   494383
# 14       Ocean       1022       1          0       0       Ocean   591939
# 15     Passaic       1294       1          0       0     Passaic   504041
# 0     Atlantic         31       0          0       0    Atlantic   268539
# 19       Union       1418       0          0       0       Union   553066
# 18      Sussex        132       0          0       0      Sussex   142298
# 16       Salem         12       0          0       0       Salem    63336
# 10      Mercer        268       0          0       0      Mercer   368762
# 11   Middlesex       1277       0          0       0   Middlesex   826698
# 9    Hunterdon         97       0          0       0   Hunterdon   125051
# 7   Gloucester        114       0          0       0  Gloucester   290852
# 4     Cape May         12       0          0       0    Cape May    93705
# 2   Burlington        202       0          0       0  Burlington   446367
# 20      Warren         76       0          0       0      Warren   106293
#
#     fraction_confirmed    deaths  death_rate?
# 5             0.011734  0.000652     5.555556
# 3             0.044938  0.000591     1.315789
# 17            0.125085  0.000303     0.242131
# 6             0.239429  0.000504     0.210526
# 12            0.182872  0.000321     0.175439
# 1             0.312796  0.000430     0.137504
# 8             0.240192  0.000299     0.124533
# 13            0.170111  0.000202     0.118906
# 14            0.172653  0.000169     0.097847
# 15            0.256725  0.000198     0.077280
# 0             0.011544  0.000000     0.000000
# 19            0.256389  0.000000     0.000000
# 18            0.092763  0.000000     0.000000
# 16            0.018947  0.000000     0.000000
# 10            0.072676  0.000000     0.000000
# 11            0.154470  0.000000     0.000000
# 9             0.077568  0.000000     0.000000
# 7             0.039195  0.000000     0.000000
# 4             0.012806  0.000000     0.000000
# 2             0.045254  0.000000     0.000000
# 20            0.071500  0.000000     0.000000
